# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler,LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df=pd.read_csv("train.csv")
df.head(5)
# Out:
#           date_time is_holiday  humidity  wind_speed  wind_direction  \
# 0  02/10/2012 09:00       None        89           2             329
# 1  02/10/2012 10:00       None        67           3             330
# 2  02/10/2012 11:00       None        66           3             329
# 3  02/10/2012 12:00       None        66           3             329
# 4  02/10/2012 13:00       None        65           3             329
#
#    visibility_in_miles  dew_point  temperature  rain_p_h  snow_p_h  \
# 0                    1          1       288.28       0.0       0.0
# 1                    1          1       289.36       0.0       0.0
# 2                    2          2       289.58       0.0       0.0
# 3                    5          5       290.13       0.0       0.0
# 4                    7          7       291.14       0.0       0.0
#
#    clouds_all weather_type  traffic_volume  air_pollution_index
# 0          40       Clouds            5545                  121
# ...

# %%
df.info()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33750 entries, 0 to 33749
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   date_time            33750 non-null  object
#  1   is_holiday           33750 non-null  int32
#  2   humidity             33750 non-null  int64
#  3   wind_speed           33750 non-null  int64
#  4   wind_direction       33750 non-null  int64
#  5   visibility_in_miles  33750 non-null  int64
#  6   dew_point            33750 non-null  int64
#  7   temperature          33750 non-null  float64
#  8   rain_p_h             33750 non-null  float64
#  9   snow_p_h             33750 non-null  float64
#  10  clouds_all           33750 non-null  int64
#  11  weather_type         33750 non-null  int32
#  12  traffic_volume       33750 non-null  int64
#  13  air_pollution_index  33750 non-null  int64
# dtypes: float64(3), int32(2), int64(8), object(1)
# memory usage: 3.6+ MB
# ...

# %%
df.describe()
# Out:
#            humidity    wind_speed  wind_direction  visibility_in_miles  \
# count  33750.000000  33750.000000    33750.000000         33750.000000
# mean      71.209007      3.378193      199.471852             4.989748
# std       16.852248      2.055792       99.841088             2.570021
# min       13.000000      0.000000        0.000000             1.000000
# 25%       60.000000      2.000000      130.000000             3.000000
# 50%       72.000000      3.000000      200.000000             5.000000
# 75%       85.000000      5.000000      290.000000             7.000000
# max      100.000000     16.000000      360.000000             9.000000
#
#           dew_point   temperature      rain_p_h      snow_p_h    clouds_all  \
# count  33750.000000  33750.000000  33750.000000  33750.000000  33750.000000
# mean       4.989748    280.069587      0.448739      0.000318     50.458785
# std        2.570021     13.415256     53.526500      0.009760     38.871734
# ...

# %%
df.isna().sum()
# Out:
# date_time              0
# is_holiday             0
# humidity               0
# wind_speed             0
# wind_direction         0
# visibility_in_miles    0
# dew_point              0
# temperature            0
# rain_p_h               0
# snow_p_h               0
# clouds_all             0
# weather_type           0
# traffic_volume         0
# air_pollution_index    0
# dtype: int64

# %%
df = df.dropna()
df.duplicated().sum()
# Out:
# 0

# %%
columns = df.iloc[:,1:-1].select_dtypes(exclude='object').columns.values
columns
# Out:
# array(['humidity', 'wind_speed', 'wind_direction', 'visibility_in_miles',
#        'dew_point', 'temperature', 'rain_p_h', 'snow_p_h', 'clouds_all',
#        'traffic_volume'], dtype=object)

# %%
le = LabelEncoder()

# %%
for i in df.iloc[:,1:-1].columns:
    if df[i].dtype == 'object':  
        df[i] = le.fit_transform(df[i])

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
df.head(5)
# Out:
#           date_time is_holiday  humidity  wind_speed  wind_direction  \
# 0  02/10/2012 09:00       None        89           2             329
# 1  02/10/2012 10:00       None        67           3             330
# 2  02/10/2012 11:00       None        66           3             329
# 3  02/10/2012 12:00       None        66           3             329
# 4  02/10/2012 13:00       None        65           3             329
#
#    visibility_in_miles  dew_point  temperature  rain_p_h  snow_p_h  \
# 0                    1          1       288.28       0.0       0.0
# 1                    1          1       289.36       0.0       0.0
# 2                    2          2       289.58       0.0       0.0
# 3                    5          5       290.13       0.0       0.0
# 4                    7          7       291.14       0.0       0.0
#
#    clouds_all weather_type  traffic_volume  air_pollution_index
# 0          40       Clouds            5545                  121
# ...

# %%
# Divide the data into “Attributes” and “labels”
X = df.iloc[:,1:-1]
y = df.iloc[:,-1]

# %%
y.value_counts()
# Out:
# 259    141
# 11     141
# 27     140
# 91     139
# 222    138
#       ...
# 238     95
# 219     94
# 261     88
# 40      85
# 205     72
# Name: air_pollution_index, Length: 290, dtype: int64

# %%
le = LabelEncoder()
y = le.fit_transform(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
sc = StandardScaler()
X_train[columns] = sc.fit_transform(X_train[columns])
X_test[columns] = sc.fit_transform(X_test[columns])

# %%
X_test
# Out:
#        is_holiday  humidity  wind_speed  wind_direction  visibility_in_miles  \
# 10802           7  0.231539   -1.152289        1.013651            -1.558625
# 4407            7 -0.477067    0.305075        0.893140             1.575923
# 7745            7 -0.713268    0.305075        0.039523            -1.558625
# 12064           7 -0.240865   -0.180713        1.194417             0.008649
# 22623           7 -0.890420    0.305075       -0.080988             1.184105
# ...           ...       ...         ...             ...                  ...
# 2912            7  0.881094    0.790863        1.294843            -1.558625
# 26642           7  0.172489    0.305075        1.093992             0.008649
# 20001           7 -0.536117   -0.180713       -0.372222             1.184105
# 2393            7  0.881094   -1.638077       -2.019201            -0.383169
# 24329           7  0.999195   -0.180713       -0.613243            -1.558625
#
# ...

# %%
#  Linear Regression model and fit it
lr =LinearRegression()
model = lr.fit(X_train,y_train)

# %%
#data prediction
y_predict=model.predict(X_test)
y_predict
# Out:
# array([144.35324145, 145.05638915, 146.14159291, ..., 143.49343983,
#        144.1600447 , 145.2669681 ])

# %%
from sklearn.metrics import accuracy_score
r2_score(y_predict,y_test)
# Out:
# -6828.119360928492

# %%
DT=DecisionTreeRegressor()
dt=DT.fit(X_train,y_train)
dt_pred=dt.predict(X_test)
dt_acc_score=r2_score(y_test,dt_pred)*100
(dt_acc_score)
# Out:
# -102.32623823702886

# %%
RF=RandomForestRegressor()
rf=RF.fit(X_train,y_train)
rf_pred=rf.predict(X_test)
rf_acc_score=r2_score(y_test,rf_pred)*100
(rf_acc_score)
# Out:
# -4.993019123133591
